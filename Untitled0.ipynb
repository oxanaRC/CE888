# %% [markdown]
# <a href="https://colab.research.google.com/github/oxanaRC/CE888/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(0, 2*np.pi, 50)
x = np.sin(t)
y = np.cos(t)

# Now create a figure
plt.figure()
# and plot x inside it
plt.plot(x)

# %%
# Now create a new figure
plt.figure()
# and plot y inside it...
plt.plot(y)
# Add a title
plt.title("Cos")
# Out:
# Text(0.5, 1.0, 'Cos')

# %%
x = np.linspace(0, 2*np.pi, 50)
y1 = np.sin(x)
y2 = np.sin(2*x)
plt.figure() # Create figure
plt.plot(y1)
plt.plot(x, y1)

# red dot-dash circle
plt.plot(x, y1, 'r')

# red marker only circle
plt.plot(x, y1, 'r-o')

# clear figure then plot 2 curves
plt.clf()
plt.plot(x, y1, 'g-o', x, y2, 'b-+')
plt.legend(['sin(x)','sin(2x)'])
